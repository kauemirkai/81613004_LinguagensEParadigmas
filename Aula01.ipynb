# %%
'hello'
# Out:
# 'hello'

# %%
a="hello"

# %%
a
# Out:
# 'hello'

# %%
a=5 
b="batata"

# %%
a b
# Out:
#   File "<ipython-input-7-90ce62edf2fe>", line 1
#     a b
#       ^
# SyntaxError: invalid syntax

# %%
a='helloWorld'

# %%
a
# Out:
# 'helloWorld'

# %%
print(a)
# Out:
# helloWorld

# %%
print("hello  \n"+a)
# Out:
# hello
# helloWorld

# %%
b=5

# %%
a="5"

# %%
a
# Out:
# '5'

# %%
int(a)
# Out:
# 5

# %%
len(a)
# Out:
# 1

# %%
len batata
# Out:
#   File "<ipython-input-21-b20bff229305>", line 1
#     len batata
#              ^
# SyntaxError: invalid syntax

# %%
len (Obatata)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-a61a9743122e> in <module>()
# ----> 1 len (Obatata)
#
# NameError: name 'Obatata' is not defined

# %%
len ("batata")
# Out:
# 6

# %%
a[0]
# Out:
# '5'

# %%
a="helloworld"

# %%
a[3:]
# Out:
# 'loworld'

# %%
a[:h]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-9a25c51f0b8d> in <module>()
# ----> 1 a[:h]
#
# NameError: name 'h' is not defined

# %%
a[:1
 ]
# Out:
# 'h'

# %%
a[1:5]
# Out:
# 'ello'

# %%
a[:-1]
# Out:
# 'helloworl'

# %%
a[-1:]
# Out:
# 'd'

# %%
a[:20]
# Out:
# 'helloworld'

# %%
a[20:]
# Out:
# ''

# %%
a[::2]
# Out:
# 'hlool'

# %%
--
# Out:
#   File "<ipython-input-40-4071a1fba099>", line 1
#     --
#       ^
# SyntaxError: invalid syntax

# %%
a[::-1]
# Out:
# 'dlrowolleh'

# %%
""" 

asdjauhdas

"""
# Out:
# ' \n\nasdjauhdas\n\n'

# %%
#test

# %%
"""test"""
# Out:
# 'test'

# %% [markdown]
# huacuhsuhdauhds

# %%
a+ "hello again"
# Out:
# 'helloworldhello again'

# %%
a = a*20

# %%
a
# Out:
# 'helloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworld'

# %%
a.upper
# Out:
# <function str.upper>

# %%
a.upper()
a.lower()
# Out:
# 'helloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworld'

# %%
a.split()
# Out:
# ['helloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworldhelloworld']

# %%
a.add(b)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-73f363cda532> in <module>()
# ----> 1 a.add(b)
#
# AttributeError: 'str' object has no attribute 'add'

# %%
a.split("h") [1:4]
# Out:
# ['elloworld', 'elloworld', 'elloworld']
